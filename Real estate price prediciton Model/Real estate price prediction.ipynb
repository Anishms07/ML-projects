# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)
from tabulate import tabulate

# %%
df=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\bengaluru_house_prices.csv")

# %%
#tabulate(df,headers='keys',tablefmt='grid')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df2=df.drop(['area_type','availability','society','balcony'],axis=1)

# %%
df2
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df2.isna().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df3=df2.dropna()

# %%
df3.shape
# Out:
# (13246, 5)

# %%
df3
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13246 rows x 5 columns]

# %%
df3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df3['bhk']=df3['size'].apply(lambda x:int(x.split(" ")[0]))
# Out:
# C:\Users\ANISH M S\AppData\Local\Temp\ipykernel_32696\2507312172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bhk']=df3['size'].apply(lambda x:int(x.split(" ")[0]))

# %%
df3
# Out:
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
df3['bhk'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df3[df3.bhk>20]
# Out:
#                        location        size total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df3[~df3['total_sqft'].apply(is_float)].head(10)
# Out:
#                location       size      total_sqft  bath    price  bhk
# 30            Yelahanka      4 BHK     2100 - 2850   4.0  186.000    4
# 122              Hebbal      4 BHK     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar      2 BHK     1042 - 1105   2.0   54.005    2
# 165            Sarjapur      2 BHK     1145 - 1340   2.0   43.490    2
# 188            KR Puram      2 BHK     1015 - 1540   2.0   56.800    2
# 410             Kengeri      1 BHK  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road      2 BHK     1195 - 1440   2.0   63.770    2
# 648             Arekere  9 Bedroom       4125Perch   9.0  265.000    9
# 661           Yelahanka      2 BHK     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor  4 Bedroom     3090 - 5002   4.0  445.000    4

# %%
def sqt_to_num(x):
    tokens=x.split('-')
    if len(tokens)==2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %% [markdown]
# df3

# %%
df4=df3.copy()
df4['total_sqft']=df4['total_sqft'].apply(sqt_to_num)

# %%
df4.loc[30]
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft       2475.0
# bath                4.0
# price             186.0
# bhk                   4
# Name: 30, dtype: object

# %%
##so in cleaning of data
#i have removed unnessary features, na values from all rows, cleaned size and total_sqft
#for every phase i changed the dataframe

# %%
#Feature engineering

# %%
df4
# Out:
#                        location       size  total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316             Richards Town      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
df4.loc[1]
# Out:
# location      Chikka Tirupathi
# size                 4 Bedroom
# total_sqft              2600.0
# bath                       5.0
# price                    120.0
# bhk                          4
# Name: 1, dtype: object

# %%
df4.total_sqft.isna().sum()
# Out:
# 46

# %%
df4[df4.total_sqft.isna()]
# Out:
#                                            location       size  total_sqft  \
# 410                                         Kengeri      1 BHK         NaN
# 648                                         Arekere  9 Bedroom         NaN
# 775                                    Basavanagara      1 BHK         NaN
# 872                               Singapura Village      2 BHK         NaN
# 1019                                 Marathi Layout  1 Bedroom         NaN
# 1086                                     Narasapura  2 Bedroom         NaN
# 1400                                     Chamrajpet      9 BHK         NaN
# 1712                               Singena Agrahara  3 Bedroom         NaN
# 1743                                      Hosa Road      3 BHK         NaN
# 1821                                       Sarjapur  3 Bedroom         NaN
# 2310                                     Whitefield      4 BHK         NaN
# ...

# %%
df4= df4[df4.total_sqft.notnull()]

# %%
df5=df4.copy()

# %%
df5['price_per_sqft'] = df5['price']*100000/df5['total_sqft']
df5.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000

# %%
df5_stats = df5['price_per_sqft'].describe()
df5_stats
# Out:
# count    1.320000e+04
# mean     7.920759e+03
# std      1.067272e+05
# min      2.678298e+02
# 25%      4.267701e+03
# 50%      5.438331e+03
# 75%      7.317073e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
len(df5.location.unique())
# Out:
# 1298

# %%
df5.location=df5.location.apply(lambda x: x.strip())
location_stats=df5.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_stats
# Out:
# location
# Whitefield               533
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           264
# Thanisandra              235
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Kannur                     1
# whitefiled                 1
# Name: location, Length: 1287, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1047

# %%
location_stats_less_than10=location_stats[location_stats<=10]

# %%
df5.location=df5.location.apply(lambda x:'other' if x in location_stats_less_than10 else x)

# %%
len(df5.location.unique())
# Out:
# 241

# %%
#Outlier removal
#As a data scientist when you have a conversation with your business manager (who has expertise in real estate),
#he will tell you that normally square ft per bedroom is 300 (i.e. 2 bhk apartment is minimum 600 sqft. 
#If you have for example 400 sqft apartment with 2 bhk than that seems suspicious and can be removed as an outlier. 
#We will remove such outliers by keeping our minimum thresold per bhk to be 300 sqft

# %%
df5.shape
# Out:
# (13200, 7)

# %%
df6=df5[~(df5.total_sqft/df5.bhk<300)]  #removing outlier

# %%
df6.shape
# Out:
# (12456, 7)

# %%
df6.price_per_sqft.describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
#Outlier Removal Using Standard Deviation and Mean

# %%
#looking at the price persqft we can see that there is a big variation in min and max 
#so we use sd and mean to remove the outliers

# %%
import numpy as np
def remove_ppf_outliers(df):
    out_df=pd.DataFrame()
    for keys,subdf in df6.groupby('location'):
        m=np.mean(subdf.price_per_sqft)
        st=np.std(subdf.price_per_sqft)
        reduced_subdf=subdf[(subdf.price_per_sqft>(m-st))&(subdf.price_per_sqft<(m+st))]
        out_df=pd.concat([out_df,reduced_subdf],ignore_index=True)
    return out_df

# %%
df7=remove_ppf_outliers(df6)
df7
# Out:
#                   location       size  total_sqft  bath   price  bhk  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.00    4
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.00    3
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.00    3
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.00    3
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.00    2
# ...                    ...        ...         ...   ...     ...  ...
# 10237                other      2 BHK      1353.0   2.0  110.00    2
# 10238                other  1 Bedroom       812.0   1.0   26.00    1
# 10239                other      3 BHK      1440.0   2.0   63.93    3
# 10240                other      2 BHK      1075.0   2.0   48.00    2
# 10241                other      4 BHK      3600.0   5.0  400.00    4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# 3        10833.333333
# ...

# %%
df7.shape
# Out:
# (10242, 7)

# %%
#so we removed 2000 outliers which were more spread

# %%
#Now Let's check if for a given location how does the 2 BHK and 3 BHK property prices look like

# %%
def plot_scatter_chart(df,location):
    bhk2=df[(df.location==location) & (df.bhk==2)]
    bhk3=df[(df.location==location) & (df.bhk==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(df7,"Rajaji Nagar")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df8 = remove_bhk_outliers(df7)

# %%
df8.shape
# Out:
# (7317, 7)

# %%
plot_scatter_chart(df8,"Rajaji Nagar")

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(20,10)
plt.hist(df8.price_per_sqft,rwidth=0.8)
plt.xlabel("price per sqft")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
#Outlier removal in the bathroom feature

# %%
df8.bath.unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  8.,  1.,  6.,  7.,  9., 12., 16., 13.])

# %%
df8[df8.bath>10]
# Out:
#             location    size  total_sqft  bath  price  bhk  price_per_sqft
# 5277  Neeladri Nagar  10 BHK      4000.0  12.0  160.0   10     4000.000000
# 8483           other  10 BHK     12000.0  12.0  525.0   10     4375.000000
# 8572           other  16 BHK     10000.0  16.0  550.0   16     5500.000000
# 9306           other  11 BHK      6000.0  12.0  150.0   11     2500.000000
# 9637           other  13 BHK      5425.0  13.0  275.0   13     5069.124424

# %%
df8[df8.bath>df8.bhk+2]
# Out:
#            location       size  total_sqft  bath   price  bhk  price_per_sqft
# 1626  Chikkabanavar  4 Bedroom      2460.0   7.0    80.0    4     3252.032520
# 5238     Nagasandra  4 Bedroom      7000.0   8.0   450.0    4     6428.571429
# 6711    Thanisandra      3 BHK      1806.0   6.0   116.0    3     6423.034330
# 8408          other      6 BHK     11338.0   9.0  1000.0    6     8819.897689

# %%
df9=df8[df8.bath<df8.bhk+2]

# %%
df9.shape
# Out:
# (7239, 7)

# %%
#now i will drop the useless features

# %%
df10=df9.drop(['size','price_per_sqft'],axis=1)

# %%
df10
# Out:
#                   location  total_sqft  bath  price  bhk
# 0      1st Block Jayanagar      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      1235.0   2.0  148.0    2
# ...                    ...         ...   ...    ...  ...
# 10233                other      1200.0   2.0   70.0    2
# 10234                other      1800.0   1.0  200.0    1
# 10237                other      1353.0   2.0  110.0    2
# 10238                other       812.0   1.0   26.0    1
# 10241                other      3600.0   5.0  400.0    4
#
# [7239 rows x 5 columns]

# %%
dummies=pd.get_dummies(df9.location)

# %%
dummies.head(3)
# Out:
#    1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                 True               False                      False
# 1                 True               False                      False
# 2                 True               False                      False
#
#    2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
#
#    6th Phase JP Nagar  7th Phase JP Nagar  8th Phase JP Nagar  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
#
#    9th Phase JP Nagar  ...  Vishveshwarya Layout  Vishwapriya Layout  \
# 0               False  ...                 False               False
# ...

# %%
df11=pd.concat([df10,dummies.drop(['other'],axis=1)],axis=1)

# %%
df11
# Out:
#                   location  total_sqft  bath  price  bhk  1st Block Jayanagar  \
# 0      1st Block Jayanagar      2850.0   4.0  428.0    4                 True
# 1      1st Block Jayanagar      1630.0   3.0  194.0    3                 True
# 2      1st Block Jayanagar      1875.0   2.0  235.0    3                 True
# 3      1st Block Jayanagar      1200.0   2.0  130.0    3                 True
# 4      1st Block Jayanagar      1235.0   2.0  148.0    2                 True
# ...                    ...         ...   ...    ...  ...                  ...
# 10233                other      1200.0   2.0   70.0    2                False
# 10234                other      1800.0   1.0  200.0    1                False
# 10237                other      1353.0   2.0  110.0    2                False
# 10238                other       812.0   1.0   26.0    1                False
# 10241                other      3600.0   5.0  400.0    4                False
#
# ...

# %%
df12=df11.drop(['location'],axis=1)

# %%
df12.shape
# Out:
# (7239, 244)

# %%
x=df12.drop(['price'],axis=1)
y=df12.price

# %%
x
# Out:
#        total_sqft  bath  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# 0          2850.0   4.0    4                 True               False
# 1          1630.0   3.0    3                 True               False
# 2          1875.0   2.0    3                 True               False
# 3          1200.0   2.0    3                 True               False
# 4          1235.0   2.0    2                 True               False
# ...           ...   ...  ...                  ...                 ...
# 10233      1200.0   2.0    2                False               False
# 10234      1800.0   1.0    1                False               False
# 10237      1353.0   2.0    2                False               False
# 10238       812.0   1.0    1                False               False
# 10241      3600.0   5.0    4                False               False
#
#        2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# ...

# %%
y
# Out:
# 0        428.0
# 1        194.0
# 2        235.0
# 3        130.0
# 4        148.0
#          ...
# 10233     70.0
# 10234    200.0
# 10237    110.0
# 10238     26.0
# 10241    400.0
# Name: price, Length: 7239, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8629132245229442

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=10)
cross_val_score(LinearRegression(),x,y,cv=cv)
# Out:
# array([0.86291322, 0.85632943, 0.87669838, 0.80558377, 0.79969281])

# %%
#using shufflesplit will split the data into 5 folds randomly , so there can be chgances of repitation
#if we do not use shufflesplit then we can directly set cv=5 or what number of folds we want and it will divide the x,y into equal proportions without repitation

# %%
#Find best model using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
def find_the_best_model(x,y):
    algos={
        'Linear Regression':{
            'model':LinearRegression(),
            'params':{
                'fit_intercept': [True, False]
            }
        },
        'lasso':{
            'model':Lasso(),
            'params':{
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,configs in algos.items():
        gs=GridSearchCV(configs['model'],configs['params'],cv=cv,return_train_score=False)
        gs.fit(x,y)
        scores.append({
        'model_name':algo_name,
        'best score':gs.best_score_,
        'best params':gs.best_params_
        })
        #print({algo_name})
    return pd.DataFrame(scores,columns=['model_name','best score','best params'])

# %%
res=find_the_best_model(x,y)
# Out:
# {'Linear Regression'}
# {'lasso'}
# {'decision_tree'}
# C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
# ...

# %%
res
# Out:
#           model_name  best score  \
# 0  Linear Regression    0.847951
# 1              lasso    0.726747
# 2      decision_tree    0.719285
#
#                                          best params
# 0                           {'fit_intercept': False}
# 1                {'alpha': 2, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'ran...

# %%
def predict_price(location,sqft,bath,bhk):
    loc_index=np.where(x.columns==location)[0][0]
    
    p=np.zeros(len(x.columns))
    p[0]=sqft
    p[1]=bath
    p[2]=bhk
    if loc_index>=1:
        p[loc_index]=1
    return lr.predict([p])[0]

# %%
predict_price('1st Phase JP Nagar',1000, 2, 2)
# Out:
# C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 83.86570258312348

# %%
predict_price('Indira Nagar',1000, 3, 3)
# Out:
# C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 195.52689759854715

# %%
predict_price('1st Phase JP Nagar',1000, 3, 3)
# Out:
# C:\Users\ANISH M S\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 86.08062284987106

# %%
#explaination to location[0][0]

# %%
x.columns
# Out:
# Index(['total_sqft', 'bath', 'bhk', '1st Block Jayanagar',
#        '1st Phase JP Nagar', '2nd Phase Judicial Layout',
#        '2nd Stage Nagarbhavi', '5th Block Hbr Layout', '5th Phase JP Nagar',
#        '6th Phase JP Nagar',
#        ...
#        'Vijayanagar', 'Vishveshwarya Layout', 'Vishwapriya Layout',
#        'Vittasandra', 'Whitefield', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yeshwanthpur'],
#       dtype='object', length=243)

# %%
np.where(x.columns=='5th Block Hbr Layout')[0][0]
# Out:
# 7

# %%
np.where(x.columns=='5th Block Hbr Layout')[0] # it will return a arrayy inide a tuple so we write[0][0]
# Out:
# array([7], dtype=int64)

# %%
x[['total_sqft','bath','bhk']]
# Out:
#        total_sqft  bath  bhk
# 0          2850.0   4.0    4
# 1          1630.0   3.0    3
# 2          1875.0   2.0    3
# 3          1200.0   2.0    3
# 4          1235.0   2.0    2
# ...           ...   ...  ...
# 10233      1200.0   2.0    2
# 10234      1800.0   1.0    1
# 10237      1353.0   2.0    2
# 10238       812.0   1.0    1
# 10241      3600.0   5.0    4
#
# [7239 rows x 3 columns]

# %%
import pickle
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(lr,f)

# %%
import os

current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: C:\Users\ANISH M S\machine learning projects

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in x.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
